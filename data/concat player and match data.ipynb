# %%
import pandas as pd
import numpy as np

# %%
df_player = pd.read_csv("./match_player_data.csv")
df_match = pd.read_csv("./match_data.csv")

# %%
df_player.head()
# Out:
#         Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  2PA  ...  \
# 0  2021/3/13  ATL  SAC  W 121-106  240  43   84  0.512  31   51  ...
# 1  2021/3/13  SAC  ATL  L 106-121  240  43   98  0.439  36   62  ...
# 2  2021/3/13  BRK  DET   W 100-95  240  39   81  0.481  33   54  ...
# 3  2021/3/13  DET  BRK   L 95-100  240  36   89  0.404  28   57  ...
# 4  2021/3/13  CHO  TOR  W 114-104  240  39   80  0.488  18   31  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0     11.844465      9.786229     12.913090      1.305715      0.648069
# 1     13.146292     10.224833     15.433486      1.098319      0.397688
# 2     14.286708      8.617410     14.567028      1.707583      2.470382
# 3     17.443965     11.364951     17.678208      2.128882      3.006507
# 4     15.371069     10.423986     20.283917      1.910250      2.409646
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0      4.774528     19.989097    136.225000    115.782014     1.713375
# 1     10.150028     19.993132    112.081389    133.155347    -2.088681
# 2      8.449958     19.993437    115.630208    102.247847     1.433340
# 3     11.274625     20.000007     99.876458    105.998958     0.197160
# 4     24.454444     19.999069    104.307153     98.834236     0.590090
#
# [5 rows x 65 columns]

# %%
df_match.head()
# Out:
#    Unnamed: 0       Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  ...  \
# 0           0  2021/3/13  ATL  SAC  W 121-106  240  43   84  0.512  31  ...
# 1           1  2021/3/13  SAC  ATL  L 106-121  240  43   98  0.439  36  ...
# 2           2  2021/3/13  BRK  DET   W 100-95  240  39   81  0.481  33  ...
# 3           3  2021/3/13  DET  BRK   L 95-100  240  36   89  0.404  28  ...
# 4           4  2021/3/13  CHO  TOR  W 114-104  240  39   80  0.488  18  ...
#
#    2P.1  2PA.1  2P%.1  3P.1  3PA.1  3P%.1  FT.1  FTA.1  FT%.1  PTS.1
# 0    36     62  0.581     7     36  0.194    13     16  0.813    106
# 1    31     51  0.608    12     33  0.364    23     33  0.697    121
# 2    28     57  0.491     8     32  0.250    15     20  0.750     95
# 3    33     54  0.611     6     27  0.222    16     22  0.727    100
# 4    22     50  0.440    15     46  0.326    15     18  0.833    104
#
# [5 rows x 32 columns]

# %%
# drop overlapping columns from player df
to_drop = []
for col_name in df_player.columns:
    if col_name in df_match.columns:
        to_drop.append(col_name)

df_player.drop(columns=to_drop, inplace=True)

# %%
merged_raw = df_match.join(df_player)

# %%
merged_raw.head()
# Out:
#    Unnamed: 0       Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  ...  \
# 0           0  2021/3/13  ATL  SAC  W 121-106  240  43   84  0.512  31  ...
# 1           1  2021/3/13  SAC  ATL  L 106-121  240  43   98  0.439  36  ...
# 2           2  2021/3/13  BRK  DET   W 100-95  240  39   81  0.481  33  ...
# 3           3  2021/3/13  DET  BRK   L 95-100  240  36   89  0.404  28  ...
# 4           4  2021/3/13  CHO  TOR  W 114-104  240  39   80  0.488  18  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0     11.844465      9.786229     12.913090      1.305715      0.648069
# 1     13.146292     10.224833     15.433486      1.098319      0.397688
# 2     14.286708      8.617410     14.567028      1.707583      2.470382
# 3     17.443965     11.364951     17.678208      2.128882      3.006507
# 4     15.371069     10.423986     20.283917      1.910250      2.409646
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0      4.774528     19.989097    136.225000    115.782014     1.713375
# 1     10.150028     19.993132    112.081389    133.155347    -2.088681
# 2      8.449958     19.993437    115.630208    102.247847     1.433340
# 3     11.274625     20.000007     99.876458    105.998958     0.197160
# 4     24.454444     19.999069    104.307153     98.834236     0.590090
#
# [5 rows x 66 columns]

# %%
merged_raw.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Tm', 'Opp', 'Result', 'MP', 'FG', 'FGA', 'FG%',
#        '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'PTS',
#        'FG.1', 'FGA.1', 'FG%.1', '2P.1', '2PA.1', '2P%.1', '3P.1', '3PA.1',
#        '3P%.1', 'FT.1', 'FTA.1', 'FT%.1', 'PTS.1', 'FG_players', 'FGA_players',
#        'FG%_players', '3P_players', '3PA_players', '3P%_players', 'FT_players',
#        'FTA_players', 'FT%_players', 'ORB_players', 'DRB_players',
#        'TRB_players', 'AST_players', 'STL_players', 'BLK_players',
#        'TOV_players', 'PF_players', 'PTS_players', '+/-_players',
#        'TS%_players', 'eFG%_players', '3PAr_players', 'FTr_players',
#        'ORB%_players', 'DRB%_players', 'TRB%_players', 'AST%_players',
#        'STL%_players', 'BLK%_players', 'TOV%_players', 'USG%_players',
#        'ORtg_players', 'DRtg_players', 'BPM_players'],
#       dtype='object')

# %%
# drop unnecessary columns
merged_raw.drop(columns=['Unnamed: 0'], inplace=True)

# %%
merged_raw.head()
# Out:
#         Date   Tm  Opp     Result   MP  FG  FGA    FG%  2P  2PA  ...  \
# 0  2021/3/13  ATL  SAC  W 121-106  240  43   84  0.512  31   51  ...
# 1  2021/3/13  SAC  ATL  L 106-121  240  43   98  0.439  36   62  ...
# 2  2021/3/13  BRK  DET   W 100-95  240  39   81  0.481  33   54  ...
# 3  2021/3/13  DET  BRK   L 95-100  240  36   89  0.404  28   57  ...
# 4  2021/3/13  CHO  TOR  W 114-104  240  39   80  0.488  18   31  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0     11.844465      9.786229     12.913090      1.305715      0.648069
# 1     13.146292     10.224833     15.433486      1.098319      0.397688
# 2     14.286708      8.617410     14.567028      1.707583      2.470382
# 3     17.443965     11.364951     17.678208      2.128882      3.006507
# 4     15.371069     10.423986     20.283917      1.910250      2.409646
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0      4.774528     19.989097    136.225000    115.782014     1.713375
# 1     10.150028     19.993132    112.081389    133.155347    -2.088681
# 2      8.449958     19.993437    115.630208    102.247847     1.433340
# 3     11.274625     20.000007     99.876458    105.998958     0.197160
# 4     24.454444     19.999069    104.307153     98.834236     0.590090
#
# [5 rows x 65 columns]

# %%
# split into tm and opp team
df_tm = merged_raw.iloc[::2]
df_opp = merged_raw.iloc[1::2]

# %%
df_tm.reset_index(inplace=True, drop=True)
df_opp.reset_index(inplace=True, drop=True)

# %%
'''
For creating table with tm performance and opp team performance

# drop team name columns for the opp df to prevent duplication
df_opp.drop(columns=['Tm', 'Opp'], inplace=True)
for col_name in df_opp.columns:
    df_opp.rename(columns={col_name: col_name + "_opp"}, inplace=True)
# drop unnecessary columns from df_opp
df_opp.drop(columns=['Date_opp', 'Result_opp'], inplace=True)
merged_final = df_tm.join(df_opp)
# save cleaned data to csv
merged_final.to_csv("./combined_match_data.csv")
'''
# Out:
# '\nFor creating table with tm performance and opp team performance\n\n# drop team name columns for the opp df to prevent duplication\ndf_opp.drop(columns=[\'Tm\', \'Opp\'], inplace=True)\nfor col_name in df_opp.columns:\n    df_opp.rename(columns={col_name: col_name + "_opp"}, inplace=True)\n# drop unnecessary columns from df_opp\ndf_opp.drop(columns=[\'Date_opp\', \'Result_opp\'], inplace=True)\nmerged_final = df_tm.join(df_opp)\n# save cleaned data to csv\nmerged_final.to_csv("./combined_match_data.csv")\n'

# %%
df_opp.columns
# Out:
# Index(['Date', 'Tm', 'Opp', 'Result', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA',
#        '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'PTS', 'FG.1', 'FGA.1',
#        'FG%.1', '2P.1', '2PA.1', '2P%.1', '3P.1', '3PA.1', '3P%.1', 'FT.1',
#        'FTA.1', 'FT%.1', 'PTS.1', 'FG_players', 'FGA_players', 'FG%_players',
#        '3P_players', '3PA_players', '3P%_players', 'FT_players', 'FTA_players',
#        'FT%_players', 'ORB_players', 'DRB_players', 'TRB_players',
#        'AST_players', 'STL_players', 'BLK_players', 'TOV_players',
#        'PF_players', 'PTS_players', '+/-_players', 'TS%_players',
#        'eFG%_players', '3PAr_players', 'FTr_players', 'ORB%_players',
#        'DRB%_players', 'TRB%_players', 'AST%_players', 'STL%_players',
#        'BLK%_players', 'TOV%_players', 'USG%_players', 'ORtg_players',
#        'DRtg_players', 'BPM_players'],
#       dtype='object')

# %%
df_opp.drop(columns=['Date','Tm','Opp','Result'], inplace=True)
# Out:
# /Users/zhouzijian/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# get the diff between team and opp
for col_name in df_opp.columns:
    df_tm[col_name] -= df_opp[col_name]
# Out:
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_tm.head()
# Out:
#         Date   Tm  Opp     Result  MP  FG  FGA    FG%  2P  2PA  ...  \
# 0  2021/3/13  ATL  SAC  W 121-106   0   0  -14  0.073  -5  -11  ...
# 1  2021/3/13  BRK  DET   W 100-95   0   3   -8  0.077   5   -3  ...
# 2  2021/3/13  CHO  TOR  W 114-104   0   2  -16  0.103  -4  -19  ...
# 3  2021/3/13  DAL  DEN  W 116-103   0   5   -4  0.077   3   -9  ...
# 4  2021/3/13  MIN  POR  L 121-125   0   1   -3  0.029   4   11  ...
#
#    DRB%_players  TRB%_players  AST%_players  STL%_players  BLK%_players  \
# 0     -1.301826     -0.438604     -2.520396      0.207396      0.250382
# 1     -3.157257     -2.747542     -3.111181     -0.421299     -0.536125
# 2     -0.820924      0.832389      2.457729      0.017625     -1.344785
# 3      0.484389      1.324847     -3.099299     -0.020514      0.727271
# 4      5.075958      4.888764     -2.418979     -0.221194      1.184958
#
#    TOV%_players  USG%_players  ORtg_players  DRtg_players  BPM_players
# 0     -5.375500     -0.004035     24.143611    -17.373333     3.802056
# 1     -2.824667     -0.006569     15.753750     -3.751111     1.236181
# 2     11.910583      0.004181      5.725833     -8.543819     2.238097
# 3     -2.464722     -0.025951     26.161597    -15.609375     3.348806
# 4     10.364042      0.011271     -2.641875      4.036528    -0.933243
#
# [5 rows x 65 columns]

# %%
# save to csv
df_tm.to_csv("combined_match_data.csv")
